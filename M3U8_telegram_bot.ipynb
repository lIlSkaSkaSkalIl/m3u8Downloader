# %%
#@title <center><font color='red'>🛰️ M3U8 Telegram Bot</font></center> { display-mode: "form" }

# 👉 Masukkan kredensial Anda di bawah ini
API_ID = None  # @param {type:"integer"}
API_HASH = ""  # @param {type:"string"}
BOT_TOKEN = ""  # @param {type:"string"}

# 📦 Clone repo GitHub Anda
# !rm -rf m3u8Downloader
# !git clone https://github.com/lIlSkaSkaSkalIl/m3u8Downloader.git
# %cd m3u8Downloader

# 📝 Buat file config.py untuk bot
with open("config.py", "w") as f:
    f.write(f'''API_ID = {API_ID}
API_HASH = "{API_HASH}"
BOT_TOKEN = "{BOT_TOKEN}"''')

# %%
# 🔧 Install dependency dari requirements.txt + ffmpeg
# !apt-get update -y
# !apt-get install -y ffmpeg
# !pip install -r requirements.txt

# %%
# ▶️ Jalankan bot
# !python3 main.py
# Out:
# 🚀 Bot dimulai...
# [FFMPEG] 🚀 Memulai proses download dari URL:
# https://surrit.com/eba8e7fe-d0b4-46cc-812d-5541313fdbe5/1280x720/video.m3u8
