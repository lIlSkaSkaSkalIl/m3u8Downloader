# %%
# 🛰️ M3U8 Telegram Bot Launcher via Google Colab
#@title <center> </font><font color='red'> 🛰️ M3U8 Telegram Bot  </center> { display-mode: "form" }

# 👉 Masukkan kredensial di bawah ini
API_ID = None  # @param {type:"integer"}
API_HASH = ""  # @param {type:"string"}
BOT_TOKEN = ""  # @param {type:"string"}

# 📦 Clone repo GitHub Anda
# !rm -rf m3u8Downloader
# !git clone https://github.com/lIlSkaSkaSkalIl/m3u8Downloader.git
# %cd m3u8Downloader/main

# 📝 Buat file config.py untuk bot
with open("config.py", "w") as f:
    f.write(f'''
API_ID = {API_ID}
API_HASH = "{API_HASH}"
BOT_TOKEN = "{BOT_TOKEN}"
''')

# 🚀 Install dependencies
# !pip install -q pyrogram tgcrypto

# ▶️ Jalankan bot
# !python3 main.py
